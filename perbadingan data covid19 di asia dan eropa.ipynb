# %%
import matplotlib.pyplot as plt 
import pandas as pd
ds = pd.read_csv('covid19.csv')
ds
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 0                NaN            Afghanistan  33.000000  65.000000  1/22/20
# 1                NaN                Albania  41.153300  20.168300  1/22/20
# 2                NaN                Algeria  28.033900   1.659600  1/22/20
# 3                NaN                Andorra  42.506300   1.521800  1/22/20
# 4                NaN                 Angola -11.202700  17.873900  1/22/20
# ...              ...                    ...        ...        ...      ...
# 32060            NaN  Sao Tome and Principe   0.186360   6.613081  5/21/20
# 32061            NaN                  Yemen  15.552727  48.516388  5/21/20
# 32062            NaN                Comoros -11.645500  43.333300  5/21/20
# 32063            NaN             Tajikistan  38.861034  71.276093  5/21/20
# 32064            NaN                Lesotho -29.609988  28.233608  5/21/20
#
#        Confirmed  Deaths  Recovered
# ...

# %% [markdown]
# # Kasus covid19 di eropa

# %%
kasusger = ds[ds['Country/Region'] == 'Germany']
kasusger
# Out:
#       Province/State Country/Region   Lat  Long     Date  Confirmed  Deaths  \
# 120              NaN        Germany  51.0   9.0  1/22/20          0       0
# 385              NaN        Germany  51.0   9.0  1/23/20          0       0
# 650              NaN        Germany  51.0   9.0  1/24/20          0       0
# 915              NaN        Germany  51.0   9.0  1/25/20          0       0
# 1180             NaN        Germany  51.0   9.0  1/26/20          0       0
# ...              ...            ...   ...   ...      ...        ...     ...
# 30860            NaN        Germany  51.0   9.0  5/17/20     176369    7962
# 31125            NaN        Germany  51.0   9.0  5/18/20     176551    8003
# 31390            NaN        Germany  51.0   9.0  5/19/20     177778    8081
# 31655            NaN        Germany  51.0   9.0  5/20/20     178473    8144
# 31920            NaN        Germany  51.0   9.0  5/21/20     179021    8203
#
#        Recovered
# 120            0
# 385            0
# ...

# %%
kasusger1 = kasusger[kasusger['Confirmed']>1]
kasusger1
# Out:
#       Province/State Country/Region   Lat  Long     Date  Confirmed  Deaths  \
# 1710             NaN        Germany  51.0   9.0  1/28/20          4       0
# 1975             NaN        Germany  51.0   9.0  1/29/20          4       0
# 2240             NaN        Germany  51.0   9.0  1/30/20          4       0
# 2505             NaN        Germany  51.0   9.0  1/31/20          5       0
# 2770             NaN        Germany  51.0   9.0   2/1/20          8       0
# ...              ...            ...   ...   ...      ...        ...     ...
# 30860            NaN        Germany  51.0   9.0  5/17/20     176369    7962
# 31125            NaN        Germany  51.0   9.0  5/18/20     176551    8003
# 31390            NaN        Germany  51.0   9.0  5/19/20     177778    8081
# 31655            NaN        Germany  51.0   9.0  5/20/20     178473    8144
# 31920            NaN        Germany  51.0   9.0  5/21/20     179021    8203
#
#        Recovered
# 1710           0
# 1975           0
# ...

# %%
kasusger1['Date'] = pd.to_datetime(kasusger1['Date'])
kasusger1
# Out:
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_3764/2229718447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasusger1['Date'] = pd.to_datetime(kasusger1['Date'])
#       Province/State Country/Region   Lat  Long       Date  Confirmed  Deaths  \
# 1710             NaN        Germany  51.0   9.0 2020-01-28          4       0
# 1975             NaN        Germany  51.0   9.0 2020-01-29          4       0
# 2240             NaN        Germany  51.0   9.0 2020-01-30          4       0
# 2505             NaN        Germany  51.0   9.0 2020-01-31          5       0
# 2770             NaN        Germany  51.0   9.0 2020-02-01          8       0
# ...              ...            ...   ...   ...        ...        ...     ...
# ...

# %%
kasusger1 ['BaseDate'] =  pd.to_datetime('2020-01-2')
kasusger1
# Out:
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_3764/765856657.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasusger1 ['BaseDate'] =  pd.to_datetime('2020-01-2')
#       Province/State Country/Region   Lat  Long       Date  Confirmed  Deaths  \
# 1710             NaN        Germany  51.0   9.0 2020-01-28          4       0
# 1975             NaN        Germany  51.0   9.0 2020-01-29          4       0
# 2240             NaN        Germany  51.0   9.0 2020-01-30          4       0
# 2505             NaN        Germany  51.0   9.0 2020-01-31          5       0
# 2770             NaN        Germany  51.0   9.0 2020-02-01          8       0
# ...              ...            ...   ...   ...        ...        ...     ...
# ...

# %%
kasusger1['Harike'] = kasusger1['Date'] - kasusger1['BaseDate']
kasusger1.head()
# Out:
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_3764/250245264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasusger1['Harike'] = kasusger1['Date'] - kasusger1['BaseDate']
#      Province/State Country/Region   Lat  Long       Date  Confirmed  Deaths  \
# 1710            NaN        Germany  51.0   9.0 2020-01-28          4       0
# 1975            NaN        Germany  51.0   9.0 2020-01-29          4       0
# 2240            NaN        Germany  51.0   9.0 2020-01-30          4       0
# 2505            NaN        Germany  51.0   9.0 2020-01-31          5       0
# 2770            NaN        Germany  51.0   9.0 2020-02-01          8       0
#
#       Recovered   BaseDate  Harike
# 1710          0 2020-01-02 26 days
# ...

# %%
kasusger1.Harike = kasusger1.Harike/pd.Timedelta(1, unit='d')
kasusger1
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#       Province/State Country/Region   Lat  Long       Date  Confirmed  Deaths  \
# 1710             NaN        Germany  51.0   9.0 2020-01-28          4       0
# 1975             NaN        Germany  51.0   9.0 2020-01-29          4       0
# 2240             NaN        Germany  51.0   9.0 2020-01-30          4       0
# 2505             NaN        Germany  51.0   9.0 2020-01-31          5       0
# 2770             NaN        Germany  51.0   9.0 2020-02-01          8       0
# ...              ...            ...   ...   ...        ...        ...     ...
# ...

# %% [markdown]
# #  Kasus covid di benua Asia

# %%
kasusjpn = ds[ds['Country/Region'] == 'Japan']
kasusjpn
# Out:
#       Province/State Country/Region   Lat   Long     Date  Confirmed  Deaths  \
# 139              NaN          Japan  36.0  138.0  1/22/20          2       0
# 404              NaN          Japan  36.0  138.0  1/23/20          2       0
# 669              NaN          Japan  36.0  138.0  1/24/20          2       0
# 934              NaN          Japan  36.0  138.0  1/25/20          2       0
# 1199             NaN          Japan  36.0  138.0  1/26/20          4       0
# ...              ...            ...   ...    ...      ...        ...     ...
# 30879            NaN          Japan  36.0  138.0  5/17/20      16285     744
# 31144            NaN          Japan  36.0  138.0  5/18/20      16305     749
# 31409            NaN          Japan  36.0  138.0  5/19/20      16367     768
# 31674            NaN          Japan  36.0  138.0  5/20/20      16367     768
# 31939            NaN          Japan  36.0  138.0  5/21/20      16424     777
#
#        Recovered
# 139            0
# ...

# %%
kasusjpn1 = kasusjpn[kasusjpn['Confirmed']>0]
kasusjpn1
# Out:
#       Province/State Country/Region   Lat   Long     Date  Confirmed  Deaths  \
# 139              NaN          Japan  36.0  138.0  1/22/20          2       0
# 404              NaN          Japan  36.0  138.0  1/23/20          2       0
# 669              NaN          Japan  36.0  138.0  1/24/20          2       0
# 934              NaN          Japan  36.0  138.0  1/25/20          2       0
# 1199             NaN          Japan  36.0  138.0  1/26/20          4       0
# ...              ...            ...   ...    ...      ...        ...     ...
# 30879            NaN          Japan  36.0  138.0  5/17/20      16285     744
# 31144            NaN          Japan  36.0  138.0  5/18/20      16305     749
# 31409            NaN          Japan  36.0  138.0  5/19/20      16367     768
# 31674            NaN          Japan  36.0  138.0  5/20/20      16367     768
# 31939            NaN          Japan  36.0  138.0  5/21/20      16424     777
#
#        Recovered
# 139            0
# ...

# %%
kasusjpn1['Date'] = pd.to_datetime(kasusjpn1['Date'])
kasusjpn1
# Out:
#       Province/State Country/Region   Lat   Long       Date  Confirmed  \
# 139              NaN          Japan  36.0  138.0 2020-01-22          2
# 404              NaN          Japan  36.0  138.0 2020-01-23          2
# 669              NaN          Japan  36.0  138.0 2020-01-24          2
# 934              NaN          Japan  36.0  138.0 2020-01-25          2
# 1199             NaN          Japan  36.0  138.0 2020-01-26          4
# ...              ...            ...   ...    ...        ...        ...
# 30879            NaN          Japan  36.0  138.0 2020-05-17      16285
# 31144            NaN          Japan  36.0  138.0 2020-05-18      16305
# 31409            NaN          Japan  36.0  138.0 2020-05-19      16367
# 31674            NaN          Japan  36.0  138.0 2020-05-20      16367
# 31939            NaN          Japan  36.0  138.0 2020-05-21      16424
#
#        Deaths  Recovered
# 139         0          0
# 404         0          0
# 669         0          0
# ...

# %%
kasusjpn1 ['BaseDate'] =  pd.to_datetime('2020-01-22')
kasusjpn1
# Out:
#       Province/State Country/Region   Lat   Long       Date  Confirmed  \
# 139              NaN          Japan  36.0  138.0 2020-01-22          2
# 404              NaN          Japan  36.0  138.0 2020-01-23          2
# 669              NaN          Japan  36.0  138.0 2020-01-24          2
# 934              NaN          Japan  36.0  138.0 2020-01-25          2
# 1199             NaN          Japan  36.0  138.0 2020-01-26          4
# ...              ...            ...   ...    ...        ...        ...
# 30879            NaN          Japan  36.0  138.0 2020-05-17      16285
# 31144            NaN          Japan  36.0  138.0 2020-05-18      16305
# 31409            NaN          Japan  36.0  138.0 2020-05-19      16367
# 31674            NaN          Japan  36.0  138.0 2020-05-20      16367
# 31939            NaN          Japan  36.0  138.0 2020-05-21      16424
#
#        Deaths  Recovered   BaseDate
# 139         0          0 2020-01-22
# 404         0          0 2020-01-22
# ...

# %%
kasusjpn1['Harike'] = kasusjpn1['Date'] - kasusjpn1['BaseDate']
kasusjpn1.head()
# Out:
#      Province/State Country/Region   Lat   Long       Date  Confirmed  Deaths  \
# 139             NaN          Japan  36.0  138.0 2020-01-22          2       0
# 404             NaN          Japan  36.0  138.0 2020-01-23          2       0
# 669             NaN          Japan  36.0  138.0 2020-01-24          2       0
# 934             NaN          Japan  36.0  138.0 2020-01-25          2       0
# 1199            NaN          Japan  36.0  138.0 2020-01-26          4       0
#
#       Recovered   BaseDate Harike
# 139           0 2020-01-22 0 days
# 404           0 2020-01-22 1 days
# 669           0 2020-01-22 2 days
# 934           0 2020-01-22 3 days
# 1199          1 2020-01-22 4 days

# %%
kasusjpn1.Harike = kasusjpn1.Harike/pd.Timedelta(1, unit='d')
kasusjpn1.head()
# Out:
#      Province/State Country/Region   Lat   Long       Date  Confirmed  Deaths  \
# 139             NaN          Japan  36.0  138.0 2020-01-22          2       0
# 404             NaN          Japan  36.0  138.0 2020-01-23          2       0
# 669             NaN          Japan  36.0  138.0 2020-01-24          2       0
# 934             NaN          Japan  36.0  138.0 2020-01-25          2       0
# 1199            NaN          Japan  36.0  138.0 2020-01-26          4       0
#
#       Recovered   BaseDate  Harike
# 139           0 2020-01-22     0.0
# 404           0 2020-01-22     1.0
# 669           0 2020-01-22     2.0
# 934           0 2020-01-22     3.0
# 1199          1 2020-01-22     4.0

# %%
plt.plot(kasusger1.Harike, kasusger1.Confirmed)
plt.plot(kasusjpn1.Harike, kasusjpn1.Confirmed)
plt.xlabel('Hari Ke-')
plt.ylabel('Jumlah Kasus')
plt.legend('Germany, Japan')
plt.title('jumlah Perbandingan Kasus Covid19 Ger & Jpn')
# Out:
# Text(0.5, 1.0, 'jumlah Perbandingan Kasus Covid19 Ger & Jpn')
