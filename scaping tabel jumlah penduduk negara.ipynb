# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://id.wikipedia.org/wiki/Daftar_negara_menurut_jumlah_penduduk'
UserAgent = Request(url,headers={'User-Agent':'Mozilla/5.0'})
html_text = urlopen(UserAgent)
soup = BeautifulSoup(html_text,'html.parser')

# %%
#tabel = soup.findAll("table",{"class":"wikitable"})[0]
tabel = soup.findAll('table',{'class':'wikitable'})[0]
baris = tabel.findAll('tr')

# %%
for row in baris:
    for cell in row.findAll(['td','th']):
        cell.get_text()

# %%
tampiltabel = []
for row in baris:
    info=[]
    for cell in row.findAll(['td','th']):
        info.append(cell.get_text().strip())
    tampiltabel.append(info)

# %%
df = pd.DataFrame(tampiltabel)
display(df)
# Out:
#              0                                      1              2  \
# 0    Peringkat          Negara(atau wilayah dependen)       Populasi
# 1            1                    Tiongkok[catatan 1]  1.417.130.000
# 2            2                       India[catatan 2]  1.396.270.000
# 3            3             Amerika Serikat[catatan 3]    338.424.000
# 4            4                              Indonesia    272.229.372
# ..         ...                                    ...            ...
# 236          –                   Niue (Selandia Baru)          1,611
# 237          –                Tokelau (Selandia Baru)          1,499
# 238        195                                Vatikan            800
# 239          –  Kepulauan Cocos (Keeling) (Australia)            544
# 240          –     Kepulauan Pitcairn (Britania Raya)             50
#
#                   3                       4  \
# 0           Tanggal  % dari  penduduk dunia
# 1     Juni 19, 2022                   18.2%
# 2     Juni 19, 2022                   17.9%
# 3     Juni 19, 2022                   4.34%
# 4         Juni 2021                   3.41%
# ..              ...                     ...
# 236     1 Juli 2011               0.000021%
# 237      2 Mei 2017               0.000019%
# 238  1 Januari 2014               0.000010%
# 239  9 Agustus 2016              0.0000070%
# 240  1 Januari 2018             0.00000064%
#
#                                                      5
# 0                                               Sumber
# 1                                 Hitungan situs resmi
# 2                                 Hitungan situs resmi
# 3                                 Hitungan situs resmi
# 4                                 Hitungan situs resmi
# ..                                                 ...
# 236                                  Hasil sensus 2011
# 237                                  Hasil sensus 2016
# 238  Perkiraan resmi Diarsipkan 2017-12-06 di Wayba...
# 239                                  Hasil sensus 2016
# 240                                    Perkiraan resmi
#
# [241 rows x 6 columns]

# %%
df = pd.DataFrame(tampiltabel)
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header
df.reset_index(drop = True, inplace= True)
display(df)
# Out:
# 0   Peringkat          Negara(atau wilayah dependen)       Populasi  \
# 0           1                    Tiongkok[catatan 1]  1.417.130.000
# 1           2                       India[catatan 2]  1.396.270.000
# 2           3             Amerika Serikat[catatan 3]    338.424.000
# 3           4                              Indonesia    272.229.372
# 4           5                               Pakistan    228.032.000
# ..        ...                                    ...            ...
# 235         –                   Niue (Selandia Baru)          1,611
# 236         –                Tokelau (Selandia Baru)          1,499
# 237       195                                Vatikan            800
# 238         –  Kepulauan Cocos (Keeling) (Australia)            544
# 239         –     Kepulauan Pitcairn (Britania Raya)             50
#
# 0           Tanggal % dari  penduduk dunia  \
# 0     Juni 19, 2022                  18.2%
# 1     Juni 19, 2022                  17.9%
# 2     Juni 19, 2022                  4.34%
# 3         Juni 2021                  3.41%
# 4     Juni 19, 2022                  2.93%
# ..              ...                    ...
# 235     1 Juli 2011              0.000021%
# 236      2 Mei 2017              0.000019%
# 237  1 Januari 2014              0.000010%
# 238  9 Agustus 2016             0.0000070%
# 239  1 Januari 2018            0.00000064%
#
# 0                                               Sumber
# 0                                 Hitungan situs resmi
# 1                                 Hitungan situs resmi
# 2                                 Hitungan situs resmi
# 3                                 Hitungan situs resmi
# 4                                 Hitungan situs resmi
# ..                                                 ...
# 235                                  Hasil sensus 2011
# 236                                  Hasil sensus 2016
# 237  Perkiraan resmi Diarsipkan 2017-12-06 di Wayba...
# 238                                  Hasil sensus 2016
# 239                                    Perkiraan resmi
#
# [240 rows x 6 columns]
