# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('covid19.csv')
df
# Out:
#       Province/State         Country/Region        Lat       Long     Date  \
# 0                NaN            Afghanistan  33.000000  65.000000  1/22/20
# 1                NaN                Albania  41.153300  20.168300  1/22/20
# 2                NaN                Algeria  28.033900   1.659600  1/22/20
# 3                NaN                Andorra  42.506300   1.521800  1/22/20
# 4                NaN                 Angola -11.202700  17.873900  1/22/20
# ...              ...                    ...        ...        ...      ...
# 32060            NaN  Sao Tome and Principe   0.186360   6.613081  5/21/20
# 32061            NaN                  Yemen  15.552727  48.516388  5/21/20
# 32062            NaN                Comoros -11.645500  43.333300  5/21/20
# 32063            NaN             Tajikistan  38.861034  71.276093  5/21/20
# 32064            NaN                Lesotho -29.609988  28.233608  5/21/20
#
#        Confirmed  Deaths  Recovered
# ...

# %%
kasus1 =df[df['Country/Region'] == 'Indonesia']
kasus1
# Out:
#       Province/State Country/Region     Lat      Long     Date  Confirmed  \
# 132              NaN      Indonesia -0.7893  113.9213  1/22/20          0
# 397              NaN      Indonesia -0.7893  113.9213  1/23/20          0
# 662              NaN      Indonesia -0.7893  113.9213  1/24/20          0
# 927              NaN      Indonesia -0.7893  113.9213  1/25/20          0
# 1192             NaN      Indonesia -0.7893  113.9213  1/26/20          0
# ...              ...            ...     ...       ...      ...        ...
# 30872            NaN      Indonesia -0.7893  113.9213  5/17/20      17514
# 31137            NaN      Indonesia -0.7893  113.9213  5/18/20      18010
# 31402            NaN      Indonesia -0.7893  113.9213  5/19/20      18496
# 31667            NaN      Indonesia -0.7893  113.9213  5/20/20      19189
# 31932            NaN      Indonesia -0.7893  113.9213  5/21/20      20162
#
#        Deaths  Recovered
# 132         0          0
# 397         0          0
# ...

# %%
kasusafg = df[df['Country/Region'] == 'Afghanistan']
kasusafg
# Out:
#       Province/State Country/Region   Lat  Long     Date  Confirmed  Deaths  \
# 0                NaN    Afghanistan  33.0  65.0  1/22/20          0       0
# 265              NaN    Afghanistan  33.0  65.0  1/23/20          0       0
# 530              NaN    Afghanistan  33.0  65.0  1/24/20          0       0
# 795              NaN    Afghanistan  33.0  65.0  1/25/20          0       0
# 1060             NaN    Afghanistan  33.0  65.0  1/26/20          0       0
# ...              ...            ...   ...   ...      ...        ...     ...
# 30740            NaN    Afghanistan  33.0  65.0  5/17/20       6664     169
# 31005            NaN    Afghanistan  33.0  65.0  5/18/20       7072     173
# 31270            NaN    Afghanistan  33.0  65.0  5/19/20       7653     178
# 31535            NaN    Afghanistan  33.0  65.0  5/20/20       8145     187
# 31800            NaN    Afghanistan  33.0  65.0  5/21/20       8676     193
#
#        Recovered
# 0              0
# 265            0
# ...

# %%
kasusalb = df[df['Country/Region'] == 'Albania']
kasusalb
# Out:
#       Province/State Country/Region      Lat     Long     Date  Confirmed  \
# 1                NaN        Albania  41.1533  20.1683  1/22/20          0
# 266              NaN        Albania  41.1533  20.1683  1/23/20          0
# 531              NaN        Albania  41.1533  20.1683  1/24/20          0
# 796              NaN        Albania  41.1533  20.1683  1/25/20          0
# 1061             NaN        Albania  41.1533  20.1683  1/26/20          0
# ...              ...            ...      ...      ...      ...        ...
# 30741            NaN        Albania  41.1533  20.1683  5/17/20        946
# 31006            NaN        Albania  41.1533  20.1683  5/18/20        948
# 31271            NaN        Albania  41.1533  20.1683  5/19/20        949
# 31536            NaN        Albania  41.1533  20.1683  5/20/20        964
# 31801            NaN        Albania  41.1533  20.1683  5/21/20        969
#
#        Deaths  Recovered
# 1           0          0
# 266         0          0
# ...

# %%
kasusafg = kasusafg[kasusafg['Confirmed']>0]
kasusafg
# Out:
#       Province/State Country/Region   Lat  Long     Date  Confirmed  Deaths  \
# 8745             NaN    Afghanistan  33.0  65.0  2/24/20          1       0
# 9010             NaN    Afghanistan  33.0  65.0  2/25/20          1       0
# 9275             NaN    Afghanistan  33.0  65.0  2/26/20          1       0
# 9540             NaN    Afghanistan  33.0  65.0  2/27/20          1       0
# 9805             NaN    Afghanistan  33.0  65.0  2/28/20          1       0
# ...              ...            ...   ...   ...      ...        ...     ...
# 30740            NaN    Afghanistan  33.0  65.0  5/17/20       6664     169
# 31005            NaN    Afghanistan  33.0  65.0  5/18/20       7072     173
# 31270            NaN    Afghanistan  33.0  65.0  5/19/20       7653     178
# 31535            NaN    Afghanistan  33.0  65.0  5/20/20       8145     187
# 31800            NaN    Afghanistan  33.0  65.0  5/21/20       8676     193
#
#        Recovered
# 8745           0
# 9010           0
# ...

# %%
kasusalb = kasusalb[kasusalb['Confirmed']>0]
kasusalb
# Out:
#       Province/State Country/Region      Lat     Long     Date  Confirmed  \
# 12456            NaN        Albania  41.1533  20.1683   3/9/20          2
# 12721            NaN        Albania  41.1533  20.1683  3/10/20         10
# 12986            NaN        Albania  41.1533  20.1683  3/11/20         12
# 13251            NaN        Albania  41.1533  20.1683  3/12/20         23
# 13516            NaN        Albania  41.1533  20.1683  3/13/20         33
# ...              ...            ...      ...      ...      ...        ...
# 30741            NaN        Albania  41.1533  20.1683  5/17/20        946
# 31006            NaN        Albania  41.1533  20.1683  5/18/20        948
# 31271            NaN        Albania  41.1533  20.1683  5/19/20        949
# 31536            NaN        Albania  41.1533  20.1683  5/20/20        964
# 31801            NaN        Albania  41.1533  20.1683  5/21/20        969
#
#        Deaths  Recovered
# 12456       0          0
# 12721       0          0
# ...

# %%
kasusind['Date'] = pd.to_datetime(kasusind['Date'])
kasusalb['Date'] = pd.to_datetime(kasusalb['Date'])
kasusafg['Date'] = pd.to_datetime(kasusafg['Date'])
kasusafg.head()
# Out:
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_11024/2097395747.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasusind['Date'] = pd.to_datetime(kasusind['Date'])
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_11024/2097395747.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasusalb['Date'] = pd.to_datetime(kasusalb['Date'])
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_11024/2097395747.py:3: SettingWithCopyWarning:
# ...

# %%
kasusind['BaseDate'] = pd.to_datetime('2020-03-02')
kasusalb['BaseDate'] = pd.to_datetime('2020-03-09')
kasusafg['BaseDate'] = pd.to_datetime('2020-02-24')
kasusafg
# Out:
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_11024/8667943.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasusind['BaseDate'] = pd.to_datetime('2020-03-02')
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_11024/8667943.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasusalb['BaseDate'] = pd.to_datetime('2020-03-09')
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_11024/8667943.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
kasusind['Harike'] = kasusind['Date'] - kasusind['BaseDate']
kasusalb['Harike'] = kasusalb['Date'] - kasusalb['BaseDate']
kasusafg['Harike'] = kasusafg['Date'] - kasusafg['BaseDate']
kasusind.head()
# Out:
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_11024/1582515919.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasusind['Harike'] = kasusind['Date'] - kasusind['BaseDate']
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_11024/1582515919.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kasusalb['Harike'] = kasusalb['Date'] - kasusalb['BaseDate']
# C:\Users\Amrullah\AppData\Local\Temp/ipykernel_11024/1582515919.py:3: SettingWithCopyWarning:
# ...

# %%
kasusind.Harike = kasusind.Harike/pd.Timedelta(1, unit='d')
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
kasusind.head()
# Out:
#       Province/State Country/Region     Lat      Long       Date  Confirmed  \
# 10732            NaN      Indonesia -0.7893  113.9213 2020-03-02          2
# 10997            NaN      Indonesia -0.7893  113.9213 2020-03-03          2
# 11262            NaN      Indonesia -0.7893  113.9213 2020-03-04          2
# 11527            NaN      Indonesia -0.7893  113.9213 2020-03-05          2
# 11792            NaN      Indonesia -0.7893  113.9213 2020-03-06          4
#
#        Deaths  Recovered   BaseDate  Harike
# 10732       0          0 2020-03-02     0.0
# 10997       0          0 2020-03-02     1.0
# 11262       0          0 2020-03-02     2.0
# 11527       0          0 2020-03-02     3.0
# 11792       0          0 2020-03-02     4.0

# %%
kasusafg.Harike = kasusafg.Harike/pd.Timedelta(1, unit='d')
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
kasusafg
# Out:
#       Province/State Country/Region   Lat  Long       Date  Confirmed  Deaths  \
# 8745             NaN    Afghanistan  33.0  65.0 2020-02-24          1       0
# 9010             NaN    Afghanistan  33.0  65.0 2020-02-25          1       0
# 9275             NaN    Afghanistan  33.0  65.0 2020-02-26          1       0
# 9540             NaN    Afghanistan  33.0  65.0 2020-02-27          1       0
# 9805             NaN    Afghanistan  33.0  65.0 2020-02-28          1       0
# ...              ...            ...   ...   ...        ...        ...     ...
# 30740            NaN    Afghanistan  33.0  65.0 2020-05-17       6664     169
# 31005            NaN    Afghanistan  33.0  65.0 2020-05-18       7072     173
# 31270            NaN    Afghanistan  33.0  65.0 2020-05-19       7653     178
# 31535            NaN    Afghanistan  33.0  65.0 2020-05-20       8145     187
# 31800            NaN    Afghanistan  33.0  65.0 2020-05-21       8676     193
#
# ...

# %%
kasusalb.Harike = kasusalb.Harike/pd.Timedelta(1, unit='d')
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
kasusalb.head()
# Out:
#       Province/State Country/Region      Lat     Long       Date  Confirmed  \
# 12456            NaN        Albania  41.1533  20.1683 2020-03-09          2
# 12721            NaN        Albania  41.1533  20.1683 2020-03-10         10
# 12986            NaN        Albania  41.1533  20.1683 2020-03-11         12
# 13251            NaN        Albania  41.1533  20.1683 2020-03-12         23
# 13516            NaN        Albania  41.1533  20.1683 2020-03-13         33
#
#        Deaths  Recovered   BaseDate  Harike
# 12456       0          0 2020-03-09     0.0
# 12721       0          0 2020-03-09     1.0
# 12986       1          0 2020-03-09     2.0
# 13251       1          0 2020-03-09     3.0
# 13516       1          0 2020-03-09     4.0

# %%
plt.plot(kasusind.Harike, kasusind.Confirmed)
plt.plot(kasusalb.Harike, kasusalb.Confirmed)

plt.xlabel('Hari Ke-')
plt.ylabel('Jumlah Kasus')
plt.legend(['Indonesia, Albania'])
plt.title('Jumlah Perbandingan Covid 19 ')
# Out:
# Text(0.5, 1.0, 'Jumlah Perbandingan Covid 19 ')
